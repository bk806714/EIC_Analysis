# %% [markdown]
# ## This program gives the fitted parameter for the energy response
# ## It gives mean, std, leakage and resolution also e/h

# %%
#%matplotlib notebook
import uproot as ur
import matplotlib.pyplot as plt
import k3d
import numpy as np
import awkward as ak
import mplhep as hep
from __future__ import print_function
from scipy.optimize import curve_fit
from matplotlib.ticker import FormatStrFormatter
from matplotlib.ticker import (MultipleLocator, FormatStrFormatter,
                               AutoMinorLocator)
from matplotlib.legend_handler import HandlerLine2D
#from scipy.stats import norm
import matplotlib.lines as mlines
import matplotlib.colors as mcolors
from scipy import integrate
import mplhep as hep
hep.set_style(hep.style.CMS)
size_xlabels=40
params = {'legend.fontsize': '30',
          'figure.figsize': (15, 10),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':size_xlabels,
         'ytick.labelsize':size_xlabels,
         'axes.labelsize': size_xlabels,
         'axes.titlesize': size_xlabels}
#plt.rc_params[axis='y', which='both')
plt.style.use(hep.style.CMS)
plt.rcParams.update(params)

tick_size=4
plt.rcParams['xtick.major.size'] = 10
plt.rcParams['xtick.major.width'] = tick_size
plt.rcParams['xtick.minor.size'] = 10
plt.rcParams['xtick.minor.width'] = tick_size


plt.rcParams['ytick.major.size'] = 10
plt.rcParams['ytick.major.width'] = tick_size
plt.rcParams['ytick.minor.size'] = 10
plt.rcParams['ytick.minor.width'] = tick_size


plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"

#ax1.tick_params('both', length=20, width=2, which='major')
#ax1.tick_params('both', length=10, width=1, which='minor')

# %% [markdown]
# ## Some of input parameters
# ### 1) Input path file
# ### 2) Energy and time threshold
# ### 3) Fitting range

# %%
import plots
## ANALYZING THE INSERT WITH TUNGSTEN + STEEL DATA
FilePathReco="/home/bishnu/EIC/Data/hepmc/HCAL/FTFP_BERT_HP/"
#FilePathReco="/home/bishnu/EIC/Data/hepmc/HCAL/"
#FilePathReco="/home/bishnu/Trail/"
## PATH WHERE FIGURE ARE SAVED  
PathToPlot='/home/bishnu/UCR_EIC/Plots/'        
Time_Threshold=50 #ns

MIP=0.6 # MeV for Hcal insert 
Gev_To_MeV=1000
Sigma_For_leakage=3
Energy_Threshold=0.1*MIP  #(0.5 * MIP for calice analysis)
FIT_SIGMA=3

# %% [markdown]
# ## For resolution and leakage for constant rapidity as function of Energy
# ## Parameter 'On' gives fitted parameter with weighted sum of HCAL + HCAL Insert
# ## Parameter 'OFF' , gives with simple sum of HCAL + HCAL Insert

# %%
## FILE WITH CONSTANT ETA AND DIFFERENT ENERGY (FE + W MIXTURE )
FilePathReco="/home/bishnu/EIC/Data/hepmc/HCAL/FTFP_BERT_HP/"
theta=2.83
def get_fitted_mean_std(wt='on'):
      
    pi_means=[]
    pi_stds=[]
    pi_resolutions=[]
    pi_resolution_errors=[]
    pi_means_error=[]
    pi_stds_error=[]
    pi_leaks_per=[]
    pi_leaks_per_error=[]
    
    el_means=[]
    el_stds=[]
    el_resolutions=[]
    el_resolution_errors=[]
    el_means_error=[]
    el_stds_error=[]
    el_leaks_per=[]
    el_leaks_per_error=[]
    fraction=1 #(1/10 of event is selected)
    
    #fileindex="deg_Fe-W" ## for insert file or HCAL orginal file
    extension='10W_40Fe'
    fileindex='deg_'+'{0}'.format(extension)
    print(fileindex)
    
    #fileindex="deg_Fe-W_Sc35_Ab156" ## for insert with absorber 15.6 mm and Sc = 0.35 mm
    #fileindex="deg_Fe-W" ## for insert WITH W 30 LAYER AND FE 20 LAYERS
    if fileindex=='deg_20W_30Fe':
        prefix='W'
    elif fileindex=='deg_Fe-W':
        prefix='FeW'
   
    ## CHOOSE THE ENERGY
    energies=[50]#,20,30,50,60,80]
    
    ## CHOOSE THE PARTICLE 
    particle='e-'
        
    for ienergy in energies:
             
        ## FOR THE HCAL Insert reading
        ene_wFe,time_wFe,PosRecoX_wFe,PosRecoY_wFe,PosRecoZ_wFe,mass_wFe,mom_wFe,energy_gen_wFe, \
        phi_wFe,ene_good_wFe=plots.read_rootfile_HCAL_Insert(fileindex,fraction,FilePathReco,ienergy,theta,particle,\
                                                         Time_Threshold,Energy_Threshold)
        
        ## THIS IS ONLY FOR THE RESOLUTION OF THE HCAL INSERT
        
        pi_mean, pi_std, pi_mean_error, pi_sigma_error, pi_leak_per, pi_leak_per_error,\
        pi_resolution,pi_resolution_error=plots.get_resolution(ene_good_wFe, ienergy, particle, Sigma_For_leakage)  
        
        '''
        ## READ HCAL 
        ene_wFe_h,time_wFe_h,PosRecoX_wFe_h,PosRecoY_wFe_h,PosRecoZ_wFe_h,mass_wFe_h,mom_wFe_h,energy_gen_wFe_h, \
        phi_wFe_h,ene_good_wFe_h=plots.read_rootfile_HCAL(fileindex,fraction,FilePathReco,ienergy,theta,particle,\
                                                         Time_Threshold,Energy_Threshold)
        
        ## RESOLUTION HCAL + HCAL INSERT
        pi_mean, pi_std, pi_mean_error, pi_sigma_error, pi_leak_per, pi_leak_per_error, pi_resolution,\
        pi_resolution_error=plots.get_resolution_hcalall_weighted(wt,ene_good_wFe_h,ene_good_wFe, ienergy, \
                                                         particle,Sigma_For_leakage) 
        '''
        
        pi_means.append(pi_mean)
        pi_stds.append(pi_std)
        pi_means_error.append(pi_mean_error)
        pi_stds_error.append(pi_sigma_error)
        pi_resolutions.append(pi_resolution)
        pi_resolution_errors.append(pi_resolution_error)
        pi_leaks_per.append(pi_leak_per)
        pi_leaks_per_error.append(pi_leak_per_error)
        
    plots.print_decimal_pi_update('{0}'.format(extension), particle, pi_means,  pi_means_error,  pi_stds,pi_stds_error, pi_leaks_per, \
                         pi_leaks_per_error, pi_resolutions, pi_resolution_errors)     
### WT ON IS FOR THE WEIGHTED SUM OF HCAL AND HCAL INSERT
get_fitted_mean_std('on')
# Out:
# deg_10W_40Fe
# HELLO JELLO 1500
# e_means_10W_40Fe=[452.69 ]
# e_means_error_10W_40Fe=[0.914 ]
# e_stds_10W_40Fe=[ 28.44 ]
# e_stds_error_10W_40Fe=[ 0.915 ]
# e_leaks_per_10W_40Fe=[ 0.667 ]
# e_leaks_per_error_10W_40Fe=[ 0.2115 ]
# e_resolutions_10W_40Fe=[ 0.06283 ]
# e_resolutions_errors_10W_40Fe=[ 0.0020 ]

# %% [markdown]
# ## Study the leakage with $\eta$ and Constant E of 50 GeV
# ## Parameter 'On' gives fitted parameter with weighted sum of HCAL + HCAL Insert
# ## Parameter 'OFF' , gives with simple sum of HCAL + HCAL Insert

# %%
## FILE WITH CONSTANT ENERGY AND DIFFERENT ETA
FilePathReco="/home/bishnu/EIC/Data/hepmc/HCAL/FTFP_BERT_HP/eta/"

def get_fitted_mean_std(wt='on'):
   
    pi_means=[]
    pi_stds=[]
    pi_resolutions=[]
    pi_resolution_errors=[]
    pi_means_error=[]
    pi_stds_error=[]
    pi_leaks_per=[]
    pi_leaks_per_error=[]
    
    el_means=[]
    el_stds=[]
    el_resolutions=[]
    el_resolution_errors=[]
    el_means_error=[]
    el_stds_error=[]
    el_leaks_per=[]
    el_leaks_per_error=[]
    
    ## fraction 1 = total events in analysis, =>  10 means Total/10 events in analysis 
    fraction=1 #(1/10 of event is selected)
    
     
    #fileindex="deg" ## for insert file or HCAL orginal file
    fileindex="deg_Fe-W" ## for insert WITH W 30 LAYER AND FE 20 LAYERS
    if fileindex=='deg':
        prefix='W'
    elif fileindex=='deg_Fe-W':
        prefix='FeW'
        
    ## Energies 
    energies=50 
   
    thetas=[2.25, 2.32, 2.56, 2.83, 3.13, 3.46, 3.82, 4.23]
    
    ## particle
    particle='pi-'
    for ithetas in thetas:
        
        
        
        ## FOR THE HCAL Insert reading
        ene_wFe,time_wFe,PosRecoX_wFe,PosRecoY_wFe,PosRecoZ_wFe,mass_wFe,mom_wFe,energy_gen_wFe, \
        phi_wFe,ene_good_wFe=plots.read_rootfile_HCAL_Insert(fileindex,fraction,FilePathReco,energies,ithetas,particle,\
                                                         Time_Threshold,Energy_Threshold)
        
        ## READ HCAL 
        ene_wFe_h,time_wFe_h,PosRecoX_wFe_h,PosRecoY_wFe_h,PosRecoZ_wFe_h,mass_wFe_h,mom_wFe_h,energy_gen_wFe_h, \
        phi_wFe_h,ene_good_wFe_h=plots.read_rootfile_HCAL(fileindex,fraction,FilePathReco,energies,ithetas,particle,\
                                                         Time_Threshold,Energy_Threshold)
       
         ## RESOLUTION HCAL + HCAL INSERT with weighted sum
        pi_mean, pi_std, pi_mean_error, pi_sigma_error, pi_leak_per, pi_leak_per_error, pi_resolution,\
        pi_resolution_error=plots.get_resolution_hcalall_weighted(wt, ene_good_wFe_h,ene_good_wFe, ithetas, \
                                                         particle,Sigma_For_leakage) 
        
        
        
        ''' 
             
        pi_mean, pi_std, pi_mean_error, pi_sigma_error, pi_leak_per, pi_leak_per_error,\
        pi_resolution,pi_resolution_error=plots.get_resolution(ene_good_wFe, ithetas, particle, Sigma_For_leakage)  
        '''
        
        
        
        
        pi_means.append(pi_mean)
        pi_stds.append(pi_std)
        pi_means_error.append(pi_mean_error)
        pi_stds_error.append(pi_sigma_error)
        pi_resolutions.append(pi_resolution)
        pi_resolution_errors.append(pi_resolution_error)
        pi_leaks_per.append(pi_leak_per)
        pi_leaks_per_error.append(pi_leak_per_error)
        
    plots.print_decimal_pi_update('thetas_wt_sum', particle, pi_means,  pi_means_error,  pi_stds,pi_stds_error, pi_leaks_per, \
                           pi_leaks_per_error, pi_resolutions, pi_resolution_errors)     
get_fitted_mean_std('on')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/uproot/source/file.py:112, in MemmapSource._open(self)
#     111 try:
# --> 112     self._file = numpy.memmap(self._file_path, dtype=self._dtype, mode="r")
#     113     self._fallback = None
#
# File ~/miniconda3/lib/python3.9/site-packages/numpy/core/memmap.py:228, in memmap.__new__(subtype, filename, dtype, mode, offset, shape, order)
#     227 else:
# --> 228     f_ctx = open(os_fspath(filename), ('r' if mode == 'c' else mode)+'b')
#     230 with f_ctx as fid:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/bishnu/EIC/Data/hepmc/HCAL/FTFP_BERT_HP/eta/insert_reco_pi-_50GeV_theta_2.25deg_Fe-W.edm4hep.root'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# File ~/miniconda3/lib/python3.9/site-packages/uproot/source/file.py:36, in FileResource.__init__(self, file_path)
#      35 try:
# ---> 36     self._file = open(self._file_path, "rb")
#      37 except uproot._util._FileNotFoundError:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/bishnu/EIC/Data/hepmc/HCAL/FTFP_BERT_HP/eta/insert_reco_pi-_50GeV_theta_2.25deg_Fe-W.edm4hep.root'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Input In [3], in <cell line: 83>()
#      79         pi_leaks_per_error.append(pi_leak_per_error)
#      81     plots.print_decimal_pi_update('thetas_wt_sum', particle, pi_means,  pi_means_error,  pi_stds,pi_stds_error, pi_leaks_per, \
#      82                            pi_leaks_per_error, pi_resolutions, pi_resolution_errors)
# ---> 83 get_fitted_mean_std('on')
#
# Input In [3], in get_fitted_mean_std(wt)
#      41 particle='pi-'
#      42 for ithetas in thetas:
#      43
#      44
#      45
#      46     ## FOR THE HCAL Insert reading
#      47     ene_wFe,time_wFe,PosRecoX_wFe,PosRecoY_wFe,PosRecoZ_wFe,mass_wFe,mom_wFe,energy_gen_wFe, \
# ---> 48     phi_wFe,ene_good_wFe=plots.read_rootfile_HCAL_Insert(fileindex,fraction,FilePathReco,energies,ithetas,particle,\
#      49                                                      Time_Threshold,Energy_Threshold)
#      51     ## READ HCAL
#      52     ene_wFe_h,time_wFe_h,PosRecoX_wFe_h,PosRecoY_wFe_h,PosRecoZ_wFe_h,mass_wFe_h,mom_wFe_h,energy_gen_wFe_h, \
#      53     phi_wFe_h,ene_good_wFe_h=plots.read_rootfile_HCAL(fileindex,fraction,FilePathReco,energies,ithetas,particle,\
#      54                                                      Time_Threshold,Energy_Threshold)
#
# File ~/UCR_EIC/EIC_Analysis/plots.py:800, in read_rootfile_HCAL_Insert(fileindex, fraction, FilePathReco, ienergy, theta, particle, Time_Threshold, Energy_Threshold)
#     798 def read_rootfile_HCAL_Insert(fileindex,fraction,FilePathReco,ienergy,theta,particle,Time_Threshold,Energy_Threshold):
#     799     FileName="insert_reco_{0}_{1}GeV_theta_{2}{3}.edm4hep.root".format(particle,ienergy,theta,fileindex)
# --> 800     events=ur.open(f"{FilePathReco}{FileName}:events")
#     801     total_Events=events.num_entries
#     802     event_cut=total_Events/fraction
#
# File ~/miniconda3/lib/python3.9/site-packages/uproot/reading.py:141, in open(path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     132 if not uproot._util.isstr(file_path) and not (
#     133     hasattr(file_path, "read") and hasattr(file_path, "seek")
#     134 ):
#     135     raise ValueError(
#     136         "'path' must be a string, pathlib.Path, an object with 'read' and "
#     137         "'seek' methods, or a length-1 dict of {{file_path: object_path}}, "
#     138         "not {0}".format(repr(path))
#     139     )
# --> 141 file = ReadOnlyFile(
#     142     file_path,
#     143     object_cache=object_cache,
#     144     array_cache=array_cache,
#     145     custom_classes=custom_classes,
#     146     decompression_executor=decompression_executor,
#     147     interpretation_executor=interpretation_executor,
#     148     **options,  # NOTE: a comma after **options breaks Python 2
#     149 )
#     151 if object_path is None:
#     152     return file.root_directory
#
# File ~/miniconda3/lib/python3.9/site-packages/uproot/reading.py:580, in ReadOnlyFile.__init__(self, file_path, object_cache, array_cache, custom_classes, decompression_executor, interpretation_executor, **options)
#     575 self.hook_before_create_source()
#     577 Source, file_path = uproot._util.file_path_to_source_class(
#     578     file_path, self._options
#     579 )
# --> 580 self._source = Source(
#     581     file_path, **self._options  # NOTE: a comma after **options breaks Python 2
#     582 )
#     584 self.hook_before_get_chunks()
#     586 if self._options["begin_chunk_size"] < _file_header_fields_big.size:
#
# File ~/miniconda3/lib/python3.9/site-packages/uproot/source/file.py:108, in MemmapSource.__init__(self, file_path, **options)
#     105 self._num_requested_bytes = 0
#     107 self._file_path = file_path
# --> 108 self._open()
#
# File ~/miniconda3/lib/python3.9/site-packages/uproot/source/file.py:118, in MemmapSource._open(self)
#     116 opts = dict(self._fallback_opts)
#     117 opts["num_workers"] = self._num_fallback_workers
# --> 118 self._fallback = uproot.source.file.MultithreadedFileSource(
#     119     self._file_path, **opts  # NOTE: a comma after **opts breaks Python 2
#     120 )
#
# File ~/miniconda3/lib/python3.9/site-packages/uproot/source/file.py:250, in MultithreadedFileSource.__init__(self, file_path, **options)
#     247 self._num_requested_bytes = 0
#     249 self._file_path = file_path
# --> 250 self._open()
#
# File ~/miniconda3/lib/python3.9/site-packages/uproot/source/file.py:254, in MultithreadedFileSource._open(self)
#     252 def _open(self):
#     253     self._executor = uproot.source.futures.ResourceThreadPoolExecutor(
# --> 254         [FileResource(self._file_path) for x in range(self._num_workers)]
#     255     )
#     256     self._num_bytes = os.path.getsize(self._file_path)
#
# File ~/miniconda3/lib/python3.9/site-packages/uproot/source/file.py:254, in <listcomp>(.0)
#     252 def _open(self):
#     253     self._executor = uproot.source.futures.ResourceThreadPoolExecutor(
# --> 254         [FileResource(self._file_path) for x in range(self._num_workers)]
#     255     )
#     256     self._num_bytes = os.path.getsize(self._file_path)
#
# File ~/miniconda3/lib/python3.9/site-packages/uproot/source/file.py:38, in FileResource.__init__(self, file_path)
#      36     self._file = open(self._file_path, "rb")
#      37 except uproot._util._FileNotFoundError:
# ---> 38     raise uproot._util._file_not_found(file_path)
#
# FileNotFoundError: file not found
#
#     '/home/bishnu/EIC/Data/hepmc/HCAL/FTFP_BERT_HP/eta/insert_reco_pi-_50GeV_theta_2.25deg_Fe-W.edm4hep.root'
#
# Files may be specified as:
#    * str/bytes: relative or absolute filesystem path or URL, without any colons
#          other than Windows drive letter or URL schema.
#          Examples: "rel/file.root", "C:\abs\file.root", "http://where/what.root"
#    * str/bytes: same with an object-within-ROOT path, separated by a colon.
#          Example: "rel/file.root:tdirectory/ttree"
#    * pathlib.Path: always interpreted as a filesystem path or URL only (no
#          object-within-ROOT path), regardless of whether there are any colons.
#          Examples: Path("rel:/file.root"), Path("/abs/path:stuff.root")
#
# Functions that accept many files (uproot.iterate, etc.) also allow:
#    * glob syntax in str/bytes and pathlib.Path.
#          Examples: Path("rel/*.root"), "/abs/*.root:tdirectory/ttree"
#    * dict: keys are filesystem paths, values are objects-within-ROOT paths.
#          Example: {"/data_v1/*.root": "ttree_v1", "/data_v2/*.root": "ttree_v2"}
#    * already-open TTree objects.
#    * iterables of the above.

# %% [markdown]
# ##  Just for plotting the Gaussian distribuiton with different absorber layers combinations

# %%
FilePathReco="/home/bishnu/EIC/Data/hepmc/HCAL/FTFP_BERT_HP/"
theta=2.83
from matplotlib.lines import Line2D
def get_fitted_mean_std():
   
    fraction=1 
    energies=[10,20]#,50,60]
    #energies=[30] #,20,30,40,50,60,80,100]
    fileindex_W="deg" ## for insert file or HCAL orginal file
    fileindex_W_Fe="deg_Fe-W" ## for insert WITH W 30 LAYER AND FE 20 LAYERS
    nbins=100
    max[irow][icol]_range=1200
    
    particle='e-'
    greek_particle=plots.get_greek_particle(particle) 
    
    extensions=['40W_10Fe', '30W_20Fe', '10W_40Fe']
    colors=['red','blue','magenta']
    #fileindex='deg_'+'{0}'.format(extension)
    nrows=2
    ncols=2
    fig,ax[irow][icol] = plt.subplots(nrows,ncols,figsize=(20,18),sharey=True,sharex=True)
    
    
    
    for ienergy in energies:
        iE=energies.index(ienergy)
        if iE<nrows:
            irow=0
            icol=iE
        else:
            irow=1
            icol=iE-ncols
        for extension in extensions:
            if extension=='30W_20Fe':
                fileindex='deg'
            else:
                fileindex='deg_'+'{0}'.format(extension)
            index = extensions.index(extension)
            print(index)
            ## FOR THE HCAL Insert mixture W-Fe
            ene,time,PosRecoX,PosRecoY,PosRecoZ,mass,mom,energy_gen,phi,ene_good=plots.read_rootfile_HCAL_Insert\
            (fileindex,fraction,FilePathReco,ienergy,theta,particle,Time_Threshold,Energy_Threshold)


            ene_total = ak.sum(ene_good,ax[irow][icol]is=-1)

            count, bins,_= ax[irow][icol].hist(np.array(ene_total),bins=nbins,alpha=0.5,range=(0,max_range),\
            label=extensions[index],linewidth='4',color=colors[index], histtype='step', density=True)
            binscenters = np.array([0.5 * (bins[i] + bins[i+1]) for i in range(len(bins)-1)])
            ax[irow][icol].set_xlabel("Event energy (MeV)",fontsize=50)
            ax[irow][icol].set_ylabel("Entries",fontsize=50)
            ax[irow][icol].set_title("{0}, {1}GeV".format(greek_particle,ienergy))

            # Create new legend handles but use the colors from the existing ones
            handles, labels = ax[irow][icol].get_legend_handles_labels()
            new_handles = [Line2D([], [], c=h.get_edgecolor()) for h in handles] 
            
            plt.legend(handles=new_handles, labels=labels)
    #plt.legend(loc='upper right')        #plt.show()
    plt.show()     
        
get_fitted_mean_std()
# Out:
#   Input In [37]
#     max[irow][icol]_range=1200
#                    ^
# SyntaxError: invalid syntax
